# %% [markdown]
# # **Day 04 – NumPy Practice**

# %% [markdown]
# # **1-Numpy OPerations**

# %% [markdown]
# # Basic Operations

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6])
arr2 = np.array([4,5,6,7,8,9])

# %%
# Subtraction

arr1 - arr2
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %%
# Multiplication
# vector Multiplication

arr1*arr2
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %%
# Scalar Multiplication
arr1*2
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
arr2 > 3
# Out:
# array([ True,  True,  True,  True,  True,  True])

# %%
# Dot Multiplication of matrices in numpy

arr3 = np.arange(6).reshape(2,3)
arr4 = np.arange(6,12).reshape(3,2)

# %%
arr3.dot(arr4)
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1.dot(arr2)
# Out:
# np.int64(154)

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %% [markdown]
# # Unary Operations
#
#
# *  A.max( )
# *  B.min( )
# *  C.sum( )

# %%
arr4.max()
# Out:
# np.int64(11)

# %%
arr4.min()
# Out:
# np.int64(6)

# %%
arr4.min(axis=0)
# Out:
# array([6, 7])

# %%
arr4.min(axis=1)
# Out:
# array([ 6,  8, 10])

# %%
arr4.sum()
# Out:
# np.int64(51)

# %%
arr4.sum(axis=0)
# Out:
# array([24, 27])

# %%
# Mean
arr4.mean()
# Out:
# np.float64(8.5)

# %%
# Standard deviation
arr4.std()
# Out:
# np.float64(1.707825127659933)

# %% [markdown]
# # Universal Functions
# *   np.exp(A)
# *   np.sin(B)
# *   np.sqrt(C)

# %%
# Find Sin value
np.sin(arr4)
# Out:
# array([[-0.2794155 ,  0.6569866 ],
#        [ 0.98935825,  0.41211849],
#        [-0.54402111, -0.99999021]])

# %%
# Find Median
np.median(arr4)
# Out:
# np.float64(8.5)

# %%
# Exponent
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])

# %% [markdown]
# # **2-Reshaping Numpy Arrays**
#
#
# *   Ravel
# *   Reshape
#
#
# *   Transpose
# *   Stacking
# *   Splitting

# %%
# Dimenstion of array 4

arr4.ndim
# Out:
# 2

# %%
# Know change the shape of array 4 with "Ravel Function" which change the Higher dimention arrays into ID(1-dimention)
# Ravel
arr4.ravel()
# Out:
# array([ 6,  7,  8,  9, 10, 11])

# %%
# Reshape

arr4.reshape(2,3)
# Out:
# array([[ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
# Transpose

arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr4.transpose()
# Out:
# array([[ 6,  8, 10],
#        [ 7,  9, 11]])

# %%
# Stacking is a trick of combining two arrays of the same shape.

arr5 = np.arange(12,18).reshape(2,3)

# %%
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr5
# Out:
# array([[12, 13, 14],
#        [15, 16, 17]])

# %%
# Horizontally stack

np.hstack((arr3,arr5))
# Out:
# array([[ 0,  1,  2, 12, 13, 14],
#        [ 3,  4,  5, 15, 16, 17]])

# %%
# vertically stack

np.vstack((arr3,arr5))
# Out:
# array([[ 0,  1,  2],
#        [ 3,  4,  5],
#        [12, 13, 14],
#        [15, 16, 17]])

# %%
# Splitting
# Horizontal split

np.hsplit(arr3,3)
# Out:
# [array([[0],
#         [3]]),
#  array([[1],
#         [4]]),
#  array([[2],
#         [5]])]

# %%
# Vertical Split

np.vsplit(arr3 ,2)
# Out:
# [array([[0, 1, 2]]), array([[3, 4, 5]])]
